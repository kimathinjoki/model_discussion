# %%
import os
from typing import List, Dict, Tuple
import random
import asyncio
import re
import numpy as np
from openai import AsyncOpenAI
from anthropic import AsyncAnthropic
import google.generativeai as genai
from dotenv import load_dotenv

# %%
load_dotenv()

# Initialize API clients
openai_client = AsyncOpenAI(api_key=os.getenv("SELF_RAG_OPENAI_API_KEY"))
anthropic_client = AsyncAnthropic(api_key=os.getenv("NEZ_CLAUDE_API_KEY"))
genai.configure(api_key=os.getenv("GEMINI_API"))

# %%
class ModelDiscussionSystem:
    def __init__(self):
        self.model_map = {
            "R1": "OpenAI",
            "R2": "Claude",
            "R3": "Gemini"
        }
        self.reverse_map = {v: k for k, v in self.model_map.items()}
        
        # Scoring criteria and weights
        self.scoring_criteria = {
            "factual_accuracy": 0.35,
            "explanation_quality": 0.25,
            "practical_examples": 0.20,
            "technical_depth": 0.20
        }
        
        # Minimum score difference required for a clear winner
        self.min_score_difference = 5.0
        
        # Categories for detailed evaluation
        self.evaluation_categories = [
            "factual_accuracy",
            "explanation_quality",
            "practical_examples",
            "technical_depth",
            "clarity",
            "completeness"
        ]
        
        # Score extraction patterns
        self.score_patterns = [
            r'(\d+)\s*(?:points|\/100|%)?',
            r'score:?\s*(\d+)',
            r'rated:?\s*(\d+)',
            r'(\d+)\s*out of\s*100'
        ]
    
    async def get_initial_responses(self, prompt: str) -> Dict[str, str]:
        """Get initial responses from all three models."""
        tasks = [
            self._get_openai_response(prompt),
            self._get_claude_response(prompt),
            self._get_gemini_response(prompt)
        ]
        responses = await asyncio.gather(*tasks)
        
        # Randomly assign response labels
        labels = list(self.reverse_map.values())
        random.shuffle(labels)
        
        return {labels[i]: resp for i, resp in enumerate(responses)}

    async def _get_openai_response(self, prompt: str) -> str:
        """Get response from OpenAI's GPT model."""
        response = await openai_client.chat.completions.create(
            model="chatgpt-4o-latest",
            messages=[{"role": "user", "content": prompt}]
        )
        return response.choices[0].message.content

    async def _get_claude_response(self, prompt: str) -> str:
        """Get response from Anthropic's Claude model."""
        response = await anthropic_client.messages.create(
            model="claude-3-5-sonnet-20241022",
            max_tokens=1000,
            messages=[{"role": "user", "content": prompt}]
        )
        return response.content[0].text

    async def _get_gemini_response(self, prompt: str) -> str:
        """Get response from Google's Gemini model."""
        model = genai.GenerativeModel('gemini-2.0-pro-exp-02-05')
        response = await model.generate_content_async(prompt)
        return response.text

    def _create_discussion_prompt(self, responses: Dict[str, str]) -> str:
        """Create enhanced prompt for models to discuss the best response."""
        formatted_responses = "\n\n".join([
            f"=== Response {label} ===\n{response}\n"
            for label, response in responses.items()
        ])
        
        criteria_list = "\n".join([
            f"- {c.replace('_', ' ').title()} (Score 1-100)" 
            for c in self.evaluation_categories
        ])
        
        weights_list = "\n".join([
            f"- {c.replace('_', ' ').title()}: {w*100}%"
            for c, w in self.scoring_criteria.items()
        ])
        
        return f"""Analyze these three responses to the same prompt and provide a detailed evaluation. 
        Don't reveal which model you are, and refer to responses only by their labels (R1, R2, R3).

        {formatted_responses}

        Please provide your analysis following EXACTLY this format:

        === DETAILED SCORING ===
        Score each response in every category (1-100):

        R1:
        {criteria_list}
        Overall Score: [Calculate weighted average]

        R2:
        {criteria_list}
        Overall Score: [Calculate weighted average]

        R3:
        {criteria_list}
        Overall Score: [Calculate weighted average]

        === WEIGHTED ANALYSIS ===
        Consider these weights in your evaluation:
        {weights_list}

        === CONSENSUS EVALUATION ===
        TOP RESPONSE: [Write exactly "I choose RX" where X is 1, 2, or 3]
        Score Difference from Runner-up: [Calculate difference]
        Confidence Level: [High/Medium/Low based on score difference]

        === QUALITATIVE ANALYSIS ===
        STRENGTHS of winning response:
        1. [First major strength]
        2. [Second major strength]
        3. [Third major strength]

        IMPROVEMENTS NEEDED:
        1. [First specific improvement]
        2. [Second specific improvement]
        3. [Third specific improvement]

        === COMPARATIVE INSIGHTS ===
        [Explain why the winning response outperformed others]"""

    def _extract_scores(self, text: str, label: str, category: str) -> List[int]:
        """Extract scores using multiple patterns."""
        scores = []
        for pattern in self.score_patterns:
            # Create category-specific pattern
            category_pattern = rf"{label.lower()}.*?{category.replace('_', ' ')}.*?{pattern}"
            matches = re.findall(category_pattern, text.lower())
            for match in matches:
                try:
                    score = int(match)
                    if 0 <= score <= 100:  # Validate score range
                        scores.append(score)
                except ValueError:
                    continue
        return scores

    def _clean_text(self, text: str) -> str:
        """Clean text by removing markdown and extra whitespace."""
        cleaned = text.strip()
        cleaned = re.sub(r'[*#\-_]', '', cleaned)
        cleaned = re.sub(r'\s+', ' ', cleaned)
        return cleaned.strip()

    def _extract_points(self, text: str, section_type: str) -> List[str]:
        """Extract and clean points from a section."""
        points = []
        if section_type.lower() in text.lower():
            section = text.lower().split(section_type.lower())[1]
            section = section.split("===")[0] if "===" in section else section
            
            # Split by numbers or bullet points
            raw_points = re.split(r'\d+\.|•|-|\*', section)
            
            for point in raw_points:
                cleaned = self._clean_text(point)
                if (len(cleaned) > 10 and  # Minimum length
                    not any(x in cleaned.lower() for x in ["r1", "r2", "r3", "response"]) and
                    not cleaned.startswith("[")):  # Remove template placeholders
                    points.append(cleaned)
        
        return list(set(points))  # Remove duplicates

    def _analyze_discussion(self, discussion_responses: List[str]) -> Tuple[str, str, Dict]:
        """Enhanced analysis of discussion responses with multiple evaluation methods."""
        # Initialize data structures
        category_scores = {label: {cat: [] for cat in self.evaluation_categories} 
                         for label in ["R1", "R2", "R3"]}
        all_strengths = []
        all_refinements = []
        
        # Process each response
        for response in discussion_responses:
            # Extract scores for each label and category
            for label in ["R1", "R2", "R3"]:
                for category in self.evaluation_categories:
                    scores = self._extract_scores(response, label, category)
                    category_scores[label][category].extend(scores)
            
            # Extract strengths and refinements
            all_strengths.extend(self._extract_points(response, "STRENGTHS"))
            all_refinements.extend(self._extract_points(response, "IMPROVEMENTS"))
        
        # Calculate normalized scores with outlier removal
        normalized_scores = {}
        for label in ["R1", "R2", "R3"]:
            normalized_scores[label] = {}
            for category in self.evaluation_categories:
                scores = category_scores[label][category]
                if scores:
                    # Remove outliers using IQR method
                    q1 = np.percentile(scores, 25)
                    q3 = np.percentile(scores, 75)
                    iqr = q3 - q1
                    lower_bound = q1 - 1.5 * iqr
                    upper_bound = q3 + 1.5 * iqr
                    filtered_scores = [s for s in scores if lower_bound <= s <= upper_bound]
                    
                    if filtered_scores:
                        normalized_scores[label][category] = np.mean(filtered_scores)
                    else:
                        normalized_scores[label][category] = 70  # Default score
                else:
                    normalized_scores[label][category] = 70  # Default score
        
        # Calculate weighted scores
        weighted_scores = {}
        for label in ["R1", "R2", "R3"]:
            score = 0
            total_weight = 0
            for category, weight in self.scoring_criteria.items():
                if category in normalized_scores[label]:
                    score += normalized_scores[label][category] * weight
                    total_weight += weight
            weighted_scores[label] = score / total_weight if total_weight > 0 else 70
        
        # Determine winner and confidence
        sorted_scores = sorted(weighted_scores.items(), key=lambda x: x[1], reverse=True)
        winner = sorted_scores[0][0]
        runner_up = sorted_scores[1][0]
        score_difference = weighted_scores[winner] - weighted_scores[runner_up]
        
        # Determine confidence level with more granularity
        if score_difference >= 15:
            confidence = "Very High"
        elif score_difference >= 10:
            confidence = "High"
        elif score_difference >= 5:
            confidence = "Medium"
        else:
            confidence = "Low"
        
        analysis_result = {
            "winner": winner,
            "winner_model": self.model_map[winner],
            "confidence_level": confidence,
            "score_difference": score_difference,
            "weighted_scores": weighted_scores,
            "category_scores": normalized_scores,
            "overall_scores": {
                label: round(weighted_scores[label], 2) 
                for label in ["R1", "R2", "R3"]
            },
            "strengths": all_strengths[:5],  # Top 5 strengths
            "refinements": all_refinements[:5]  # Top 5 refinements
        }
        
        return winner, "\n".join(all_refinements), analysis_result

    def _create_final_prompt(self, original_prompt: str, refinements: str) -> str:
        """Create prompt for final refined response."""
        return f"""Original prompt: {original_prompt}

        Please provide a refined response incorporating ALL these improvements:
        {refinements}

        Ensure your response is:
        1. Comprehensive and detailed
        2. Well-structured and clear
        3. Incorporates all the suggested improvements
        4. Maintains technical accuracy while being accessible

        Give your best, most refined answer:"""

    async def facilitate_discussion(self, initial_responses: Dict[str, str]) -> Tuple[str, str, Dict]:
        """Facilitate enhanced discussion between models."""
        discussion_prompt = self._create_discussion_prompt(initial_responses)
        
        tasks = [
            self._get_openai_response(discussion_prompt),
            self._get_claude_response(discussion_prompt),
            self._get_gemini_response(discussion_prompt)
        ]
        discussion_responses = await asyncio.gather(*tasks)
        
        return self._analyze_discussion(discussion_responses)

    async def get_final_response(self, prompt: str, chosen_label: str, refinements: str) -> str:
        """Get final refined response from the chosen model."""
        final_prompt = self._create_final_prompt(prompt, refinements)
        chosen_model = self.model_map[chosen_label]
        
        if chosen_model == "OpenAI":
            return await self._get_openai_response(final_prompt)
        elif chosen_model == "Claude":
            return await self._get_claude_response(final_prompt)
        else:  # Gemini
            return await self._get_gemini_response(final_prompt)

# %%
async def get_model_discussion(prompt: str):
    """Enhanced utility function to run the discussion process."""
    system = ModelDiscussionSystem()
    
    print("Getting initial responses...")
    initial_responses = await system.get_initial_responses(prompt)
    print("\nInitial Responses:")
    for label, response in initial_responses.items():
        model_name = system.model_map[label]
        print(f"\n{label} ({model_name}):\n{response}\n{'-'*50}")
    
    print("\nFacilitating discussion...")
    chosen_label, refinements, analysis = await system.facilitate_discussion(initial_responses)
    
    print("\n" + "="*50)
    print("ANALYSIS RESULTS")
    print("="*50)
    
    # Winner Information
    winning_model = analysis['winner_model']
    print(f"\n🏆 WINNING RESPONSE:")
    print(f"Model: {winning_model} (Response {chosen_label})")
    print(f"Confidence: {analysis['confidence_level']}")
    print(f"Margin of Victory: {analysis['score_difference']:.2f} points")
    
    # Scores
    print("\n📊 FINAL SCORES:")
    for label, score in analysis['overall_scores'].items():
        model_name = system.model_map[label]
        print(f"{label} ({model_name}): {score:.2f}")
    
    # Category Breakdown
    print(f"\n📋 CATEGORY BREAKDOWN FOR {winning_model}:")
    winner_scores = analysis['category_scores'][chosen_label]
    for category, score in winner_scores.items():
        print(f"{category.replace('_', ' ').title()}: {score:.2f}")
    
    # Strengths
    print("\n💪 STRENGTHS:")
    for i, strength in enumerate(analysis['strengths'], 1):
        print(f"{i}. {strength}")
    
    # Improvements
    print("\n📈 SUGGESTED IMPROVEMENTS:")
    for i, refinement in enumerate(analysis['refinements'], 1):
        print(f"{i}. {refinement}")
    
    # Final Response
    print(f"\n{'='*50}")
    print(f"FINAL REFINED RESPONSE FROM {winning_model.upper()}")
    print(f"{'='*50}")
    final_response = await system.get_final_response(prompt, chosen_label, refinements)
    print(f"\n{final_response}")
    
    # Return the complete analysis
    return {
        'initial_responses': initial_responses,
        'analysis': analysis,
        'final_response': final_response
    }

# %%
prompt = "Explain the concept of seasons"
result = await get_model_discussion(prompt)
result
# Out:
# Getting initial responses...
#
# Initial Responses:
#
# R3 (Gemini):
# The concept of **seasons** refers to the four distinct periods of the year—**spring, summer, autumn (fall), and winter**—that are characterized by changes in temperature, weather patterns, and daylight hours. Seasons occur due to the **tilt of Earth's axis (approximately 23.5 degrees) and its orbit around the Sun**.
#
# ### **Key Factors Behind Seasons:**
# 1. **Earth's Tilt**: The Earth's axis is tilted relative to its orbit around the Sun. This means that different parts of the planet receive varying amounts of sunlight throughout the year.
# 2. **Revolution Around the Sun**: As Earth moves around the Sun in a year-long orbit, the Sun appears to shift in the sky, causing changes in temperatures and daylight hours.
# 3. **Sunlight Intensity & Daylight Duration**: When a hemisphere is tilted toward the Sun, it experiences longer days and more direct sunlight, resulting in **warmer temperatures (summer)**. When it is tilted away, days are shorter, and the sunlight is less direct, creating **cooler conditions (winter)**.
#
# ### **The Four Seasons:**
# 1. **Spring** (~March–June in the Northern Hemisphere, ~September–December in the Southern Hemisphere)
#    - Days become longer.
#    - Temperatures gradually rise.
#    - Plants grow, and flowers bloom.
#
# 2. **Summer** (~June–September in the Northern Hemisphere, ~December–March in the Southern Hemisphere)
#    - The hottest season with the most daylight.
#    - Sunlight is more direct.
#    - Ideal time for outdoor activities and plant growth.
#
# 3. **Autumn (Fall)** (~September–December in the Northern Hemisphere, ~March–June in the Southern Hemisphere)
#    - Temperatures begin to drop.
#    - Leaves change color and fall from trees.
#    - Harvest season for many crops.
#
# 4. **Winter** (~December–March in the Northern Hemisphere, ~June–September in the Southern Hemisphere)
#    - The coldest season with shorter daylight hours.
#    - Snow and ice are common in colder regions.
#    - Many animals hibernate or migrate.
#
# ### **Seasonal Differences Between Hemispheres:**
# - When it is **summer in the Northern Hemisphere**, it is **winter in the Southern Hemisphere**, and vice versa.
# - The **equator** experiences less variation in seasons, typically maintaining warm temperatures year-round.
#
# ### **Equinoxes and Solstices:**
# - **Equinoxes** (Spring & Autumn): Occur when day and night are nearly equal in length (March & September).
# - **Solstices** (Summer & Winter): Mark the longest and shortest days of the year (June & December).
#
# Seasons affect not only **weather and climate** but also **ecosystems, agriculture, and human activities** around the world.
# --------------------------------------------------
#
# R1 (OpenAI):
# Seasons are cyclical changes in weather patterns and daylight hours that occur throughout the year. There are four main seasons in most parts of the world:
#
# 1. Spring (March-May in Northern Hemisphere):
# - Temperatures begin to warm
# - Plants start growing and flowering
# - Days get longer
# - Increased rainfall
#
# 2. Summer (June-August in Northern Hemisphere):
# - Warmest temperatures
# - Longest daylight hours
# - Peak growing season
# - Generally less rainfall
#
# 3. Fall/Autumn (September-November in Northern Hemisphere):
# - Cooling temperatures
# - Shorter days
# - Trees lose leaves
# - Plants prepare for winter
#
# 4. Winter (December-February in Northern Hemisphere):
# - Coldest temperatures
# - Shortest daylight hours
# - Possible snow/ice
# - Dormant period for many plants
#
# Seasons occur because:
# - Earth's tilted axis (23.5 degrees)
# - Earth's rotation around the Sun
# - The tilt causes different parts of Earth to receive varying amounts of sunlight throughout the year
#
# Important notes:
# - Seasons are opposite in Northern and Southern hemispheres
# - Areas near the equator experience less dramatic seasonal changes
# - Some regions have different seasonal patterns (wet/dry seasons)
# - Season lengths and characteristics vary by location
#
# The seasonal cycle affects:
# - Temperature
# - Precipitation
# - Plant and animal life cycles
# - Human activities and culture
# --------------------------------------------------
#
# R2 (Claude):
# The Earth's seasons (spring, summer, autumn/fall, and winter) are caused by a combination of two key factors:
#
# 1.  **Earth's Axial Tilt:** The Earth is not perfectly upright as it orbits the Sun.  It's tilted on its axis at an angle of approximately 23.5 degrees relative to its orbital plane (the plane of Earth's orbit around the Sun).  This tilt is *crucial*.  It means that different parts of the Earth receive different amounts of direct sunlight throughout the year.
#
# 2.  **Earth's Revolution Around the Sun:** The Earth takes approximately 365.25 days to complete one orbit (revolution) around the Sun.  As the Earth orbits, the tilted axis *always points in the same direction in space* (towards Polaris, the North Star).  This consistent tilt, combined with the Earth's movement around the Sun, is what creates the changing seasons.
#
# Here's how it works, broken down by hemisphere (the explanations are opposite for the Northern and Southern Hemispheres):
#
# **Northern Hemisphere Example (Southern Hemisphere is opposite):**
#
# *   **Summer Solstice (around June 21st):** The Northern Hemisphere is tilted *towards* the Sun.  This means:
#     *   Sunlight hits the Northern Hemisphere more directly (at a higher angle).
#     *   The days are longer (more hours of sunlight).
#     *   The Sun's energy is more concentrated, leading to warmer temperatures.  Think of shining a flashlight directly onto a surface versus at an angle – the direct beam is more intense.
#
# *   **Autumnal Equinox (around September 22nd):** The Earth has moved in its orbit.  Neither hemisphere is tilted significantly towards or away from the Sun.
#     *   Sunlight hits both hemispheres roughly equally.
#     *   Day and night are approximately equal in length (around 12 hours each) all over the world.
#     *   Temperatures begin to cool in the Northern Hemisphere as the days get shorter.
#
# *   **Winter Solstice (around December 21st):** The Northern Hemisphere is tilted *away* from the Sun. This means:
#     *   Sunlight hits the Northern Hemisphere at a more oblique (lower) angle.
#     *   The days are shorter (fewer hours of sunlight).
#     *   The Sun's energy is spread out over a larger area, leading to cooler temperatures.
#
# *   **Vernal Equinox (around March 20th):** The Earth continues its orbit. Again, neither hemisphere is tilted significantly towards or away from the Sun.
#     *   Sunlight hits both hemispheres roughly equally.
#     *   Day and night are approximately equal in length.
#     *   Temperatures begin to warm in the Northern Hemisphere as the days get longer.
#
# **Key Concepts and Clarifications:**
#
# *   **Solstices:** The solstices mark the points in Earth's orbit where one hemisphere experiences its longest day (summer solstice) and its shortest day (winter solstice).
# *   **Equinoxes:** The equinoxes mark the points where day and night are of equal length all over the world.  "Equinox" literally means "equal night."
# *   **Distance from the Sun is NOT the primary cause:** The Earth's orbit around the Sun is slightly elliptical (oval-shaped), so the Earth *is* slightly closer to the Sun at certain times of the year. However, this difference in distance is *very small* and has a negligible effect on the seasons. The axial tilt is the overwhelming factor.  In fact, the Northern Hemisphere is slightly *further* from the sun during its summer.
# *   **Tropics vs. Temperate Zones:** The tropics (regions near the equator) experience less seasonal variation because they receive relatively direct sunlight year-round. Temperate zones (between the tropics and the polar regions) experience the most pronounced seasonal changes. The polar regions experience extremes of daylight and darkness (24 hours of daylight in summer, 24 hours of darkness in winter).
# * **Lag of Seasons:** There is a lag between the solstices/equinoxes and the peak temperatures. This means the warmest days are usually *after* the summer solstice, and the coldest days are *after* the winter solstice. This is because the land and oceans take time to heat up and cool down.
#
# In summary, the seasons are a result of the Earth's tilted axis and its journey around the Sun. The tilt causes different parts of the Earth to receive varying amounts of direct sunlight throughout the year, leading to changes in temperature and day length.
#
# --------------------------------------------------
#
# Facilitating discussion...
#
# ==================================================
# ANALYSIS RESULTS
# ==================================================
#
# 🏆 WINNING RESPONSE:
# Model: OpenAI (Response R1)
# Confidence: Low
# Margin of Victory: 0.00 points
#
# 📊 FINAL SCORES:
# R1 (OpenAI): 70.00
# R2 (Claude): 70.00
# R3 (Gemini): 70.00
#
# 📋 CATEGORY BREAKDOWN FOR OpenAI:
# Factual Accuracy: 70.00
# Explanation Quality: 70.00
# Practical Examples: 70.00
# Technical Depth: 70.00
# Clarity: 70.00
# Completeness: 70.00
#
# 💪 STRENGTHS:
# 1. strong use of practical examples & comparisons
# 2. explained, some additional real
# 3. level explanation, mentioning polaris, sunlight angles, and concepts like seasonal lag, which provide deeper insight.
# 4. highest technical accuracy & detail
# 5. could be more concise
#
# 📈 SUGGESTED IMPROVEMENTS:
# 1. explained, some additional real
# 2. could be more concise
# 3. – while detail is important, some explanations could be slightly condensed for brevity without sacrificing clarity.
# 4. more visual/anecdotal elements
# 5. – though theoretical concepts are well
#
# ==================================================
# FINAL REFINED RESPONSE FROM OPENAI
# ==================================================
#
# # **Understanding Seasons: Why the Earth Has Changing Weather Patterns**
#
# Seasons are the result of **Earth’s axial tilt** and **its orbit around the Sun**. These factors determine how much sunlight different parts of the planet receive throughout the year, creating patterns of temperature and weather changes.
#
# ---
#
# ## 🌍 **Why Do Seasons Occur?**
#
# ### **1. Earth’s Tilt and Orbit**
# The Earth is tilted at an **angle of 23.5 degrees** relative to its orbit around the Sun. This tilt remains **constant** (a concept called **axial stability**) as the Earth moves through space. Because of this inclination:
#
# - Different regions receive **varying intensities of sunlight** at different times of the year.
# - The **hemisphere tilted toward the Sun** experiences **summer**, while the opposite hemisphere—tilted away—has **winter**.
# - When neither hemisphere is strongly tilted toward or away, milder conditions mark **spring** and **autumn**.
#
# ### **2. The Four Seasons and Their Causes**
# The Earth’s position in its orbit determines the four seasons:
#
# #### ☀️ **Summer (June–August in the Northern Hemisphere, December–February in the Southern Hemisphere)**
# - **Sunlight hits more directly**, leading to **warmer temperatures**.
# - Regions experience **longer daylight hours**.
# - Plants thrive, animals are most active, and humans often engage in outdoor activities.
#
# #### ❄️ **Winter (December–February in the Northern Hemisphere, June–August in the Southern Hemisphere)**
# - Sunlight strikes at a **less direct angle**, making temperatures **cooler**.
# - **Shorter days** with longer nights.
# - Many animals hibernate, and trees shed leaves in colder climates.
#
# #### 🌸 **Spring (March–May in the Northern Hemisphere, September–November in the Southern Hemisphere)**
# - Warmer temperatures return as sunlight intensity increases.
# - New plant growth, blooming flowers, and awakening wildlife.
# - Often seen as a time of **renewal and growth**.
#
# #### 🍂 **Autumn (September–November in the Northern Hemisphere, March–May in the Southern Hemisphere)**
# - Temperatures **gradually cool** as the Sun’s angle decreases.
# - Leaves change colors and fall off trees (in many temperate regions).
# - Animals prepare for winter by storing food or migrating.
#
# ---
#
# ## 🌎 **Seasonal Differences Around the World**
#
# Seasons vary depending on **latitude** and **proximity to large bodies of water**:
#
# - **Equator (Tropics):** Experiences **minimal seasonal temperature changes**. Instead of four seasons, regions near the equator have **wet and dry seasons**.
# - **Poles (Arctic & Antarctic):** Experience **extreme seasonal shifts**, with almost **continuous daylight in summer** and **24-hour darkness in winter**.
# - **Coastal Areas vs. Inland Regions:** Large bodies of water moderate temperature changes, leading to **milder seasons** in coastal regions but **more extreme seasons** inland.
#
# ---
#
# ## 🏞 **How Seasons Impact Life on Earth**
#
# Seasons influence **ecosystems, agriculture, and human activities**:
#
# - **Changing daylight and temperature** affect plant growth, animal migration, and weather patterns.
# - **Agriculture depends on seasonal cycles**, with planting, growing, and harvesting timed according to the seasons.
# - **Human cultures and festivals** are often tied to natural seasonal events (e.g., harvest festivals, winter holidays).
#
# ---
#
# ## 🔬 **Additional Scientific Insights**
#
# - **Seasonal Lag:** The Earth's surface retains heat, meaning the warmest and coldest periods typically **follow** the solstices by several weeks.
# - **Equinox vs. Solstice:**
#   - **Solstices (June 21 & December 21)**: When the Sun appears farthest north or south, marking the longest and shortest days.
#   - **Equinoxes (March 21 & September 21)**: When day and night are nearly equal worldwide, marking transitions between summer/winter and spring/autumn.
#
# ---
#
# ## 📌 **Visualizing Seasons**
#
# For a clearer understanding, imagine:
#
# - A tilted **globe moving around a lamp**—where different regions receive differing amounts of light throughout the journey.
# - **A changing tree through the year**—lush in summer, colorful in autumn, bare in winter, and budding again in spring.
#
# (If possible, an **illustration** of Earth's tilt and orbit would greatly enhance comprehension here! 🌎☀️)
#
# ---
#
# ## 🔑 **Conclusion**
#
# Seasons are a result of **Earth's tilt and orbit**, affecting climate, ecosystems, and daily life. While tropical areas experience minimal variation, temperate and polar regions undergo **dramatic seasonal shifts**, shaping weather, wildlife, and human traditions. Understanding this cycle helps us appreciate the changing world around us! 🌍✨
# {'initial_responses': {'R3': "The concept of **seasons** refers to the four distinct periods of the year—**spring, summer, autumn (fall), and winter**—that are characterized by changes in temperature, weather patterns, and daylight hours. Seasons occur due to the **tilt of Earth's axis (approximately 23.5 degrees) and its orbit around the Sun**.\n\n### **Key Factors Behind Seasons:**\n1. **Earth's Tilt**: The Earth's axis is tilted relative to its orbit around the Sun. This means that different parts of the planet receive varying amounts of sunlight throughout the year.\n2. **Revolution Around the Sun**: As Earth moves around the Sun in a year-long orbit, the Sun appears to shift in the sky, causing changes in temperatures and daylight hours.\n3. **Sunlight Intensity & Daylight Duration**: When a hemisphere is tilted toward the Sun, it experiences longer days and more direct sunlight, resulting in **warmer temperatures (summer)**. When it is tilted away, days are shorter, and the sunlight is less direct, creating **cooler conditions (winter)**.\n\n### **The Four Seasons:**\n1. **Spring** (~March–June in the Northern Hemisphere, ~September–December in the Southern Hemisphere)\n   - Days become longer.\n   - Temperatures gradually rise.\n   - Plants grow, and flowers bloom.\n\n2. **Summer** (~June–September in the Northern Hemisphere, ~December–March in the Southern Hemisphere)\n   - The hottest season with the most daylight.\n   - Sunlight is more direct.\n   - Ideal time for outdoor activities and plant growth.\n\n3. **Autumn (Fall)** (~September–December in the Northern Hemisphere, ~March–June in the Southern Hemisphere)\n   - Temperatures begin to drop.\n   - Leaves change color and fall from trees.\n   - Harvest season for many crops.\n\n4. **Winter** (~December–March in the Northern Hemisphere, ~June–September in the Southern Hemisphere)\n   - The coldest season with shorter daylight hours.\n   - Snow and ice are common in colder regions.\n   - Many animals hibernate or migrate.\n\n### **Seasonal Differences Between Hemispheres:**\n- When it is **summer in the Northern Hemisphere**, it is **winter in the Southern Hemisphere**, and vice versa.\n- The **equator** experiences less variation in seasons, typically maintaining warm temperatures year-round.\n\n### **Equinoxes and Solstices:**\n- **Equinoxes** (Spring & Autumn): Occur when day and night are nearly equal in length (March & September).\n- **Solstices** (Summer & Winter): Mark the longest and shortest days of the year (June & December).\n\nSeasons affect not only **weather and climate** but also **ecosystems, agriculture, and human activities** around the world.",
#   'R1': "Seasons are cyclical changes in weather patterns and daylight hours that occur throughout the year. There are four main seasons in most parts of the world:\n\n1. Spring (March-May in Northern Hemisphere):\n- Temperatures begin to warm\n- Plants start growing and flowering\n- Days get longer\n- Increased rainfall\n\n2. Summer (June-August in Northern Hemisphere):\n- Warmest temperatures\n- Longest daylight hours\n- Peak growing season\n- Generally less rainfall\n\n3. Fall/Autumn (September-November in Northern Hemisphere):\n- Cooling temperatures\n- Shorter days\n- Trees lose leaves\n- Plants prepare for winter\n\n4. Winter (December-February in Northern Hemisphere):\n- Coldest temperatures\n- Shortest daylight hours\n- Possible snow/ice\n- Dormant period for many plants\n\nSeasons occur because:\n- Earth's tilted axis (23.5 degrees)\n- Earth's rotation around the Sun\n- The tilt causes different parts of Earth to receive varying amounts of sunlight throughout the year\n\nImportant notes:\n- Seasons are opposite in Northern and Southern hemispheres\n- Areas near the equator experience less dramatic seasonal changes\n- Some regions have different seasonal patterns (wet/dry seasons)\n- Season lengths and characteristics vary by location\n\nThe seasonal cycle affects:\n- Temperature\n- Precipitation\n- Plant and animal life cycles\n- Human activities and culture",
#   'R2': 'The Earth\'s seasons (spring, summer, autumn/fall, and winter) are caused by a combination of two key factors:\n\n1.  **Earth\'s Axial Tilt:** The Earth is not perfectly upright as it orbits the Sun.  It\'s tilted on its axis at an angle of approximately 23.5 degrees relative to its orbital plane (the plane of Earth\'s orbit around the Sun).  This tilt is *crucial*.  It means that different parts of the Earth receive different amounts of direct sunlight throughout the year.\n\n2.  **Earth\'s Revolution Around the Sun:** The Earth takes approximately 365.25 days to complete one orbit (revolution) around the Sun.  As the Earth orbits, the tilted axis *always points in the same direction in space* (towards Polaris, the North Star).  This consistent tilt, combined with the Earth\'s movement around the Sun, is what creates the changing seasons.\n\nHere\'s how it works, broken down by hemisphere (the explanations are opposite for the Northern and Southern Hemispheres):\n\n**Northern Hemisphere Example (Southern Hemisphere is opposite):**\n\n*   **Summer Solstice (around June 21st):** The Northern Hemisphere is tilted *towards* the Sun.  This means:\n    *   Sunlight hits the Northern Hemisphere more directly (at a higher angle).\n    *   The days are longer (more hours of sunlight).\n    *   The Sun\'s energy is more concentrated, leading to warmer temperatures.  Think of shining a flashlight directly onto a surface versus at an angle – the direct beam is more intense.\n\n*   **Autumnal Equinox (around September 22nd):** The Earth has moved in its orbit.  Neither hemisphere is tilted significantly towards or away from the Sun.\n    *   Sunlight hits both hemispheres roughly equally.\n    *   Day and night are approximately equal in length (around 12 hours each) all over the world.\n    *   Temperatures begin to cool in the Northern Hemisphere as the days get shorter.\n\n*   **Winter Solstice (around December 21st):** The Northern Hemisphere is tilted *away* from the Sun. This means:\n    *   Sunlight hits the Northern Hemisphere at a more oblique (lower) angle.\n    *   The days are shorter (fewer hours of sunlight).\n    *   The Sun\'s energy is spread out over a larger area, leading to cooler temperatures.\n\n*   **Vernal Equinox (around March 20th):** The Earth continues its orbit. Again, neither hemisphere is tilted significantly towards or away from the Sun.\n    *   Sunlight hits both hemispheres roughly equally.\n    *   Day and night are approximately equal in length.\n    *   Temperatures begin to warm in the Northern Hemisphere as the days get longer.\n\n**Key Concepts and Clarifications:**\n\n*   **Solstices:** The solstices mark the points in Earth\'s orbit where one hemisphere experiences its longest day (summer solstice) and its shortest day (winter solstice).\n*   **Equinoxes:** The equinoxes mark the points where day and night are of equal length all over the world.  "Equinox" literally means "equal night."\n*   **Distance from the Sun is NOT the primary cause:** The Earth\'s orbit around the Sun is slightly elliptical (oval-shaped), so the Earth *is* slightly closer to the Sun at certain times of the year. However, this difference in distance is *very small* and has a negligible effect on the seasons. The axial tilt is the overwhelming factor.  In fact, the Northern Hemisphere is slightly *further* from the sun during its summer.\n*   **Tropics vs. Temperate Zones:** The tropics (regions near the equator) experience less seasonal variation because they receive relatively direct sunlight year-round. Temperate zones (between the tropics and the polar regions) experience the most pronounced seasonal changes. The polar regions experience extremes of daylight and darkness (24 hours of daylight in summer, 24 hours of darkness in winter).\n* **Lag of Seasons:** There is a lag between the solstices/equinoxes and the peak temperatures. This means the warmest days are usually *after* the summer solstice, and the cold ...
#  'analysis': {'winner': 'R1',
#   'winner_model': 'OpenAI',
#   'confidence_level': 'Low',
#   'score_difference': 0.0,
#   'weighted_scores': {'R1': 70.0, 'R2': 70.0, 'R3': 70.0},
#   'category_scores': {'R1': {'factual_accuracy': 70,
#     'explanation_quality': 70,
#     'practical_examples': 70,
#     'technical_depth': 70,
#     'clarity': 70,
#     'completeness': 70},
#    'R2': {'factual_accuracy': 70,
#     'explanation_quality': 70,
#     'practical_examples': 70,
#     'technical_depth': 70,
#     'clarity': np.float64(1.0),
#     'completeness': np.float64(3.0)},
#    'R3': {'factual_accuracy': 70,
#     'explanation_quality': 70,
#     'practical_examples': 70,
#     'technical_depth': 70,
#     'clarity': 70,
#     'completeness': 70}},
#   'overall_scores': {'R1': 70.0, 'R2': 70.0, 'R3': 70.0},
#   'strengths': ['strong use of practical examples & comparisons',
#    'explained, some additional real',
#    'level explanation, mentioning polaris, sunlight angles, and concepts like seasonal lag, which provide deeper insight.',
#    'highest technical accuracy & detail',
#    'could be more concise'],
#   'refinements': ['explained, some additional real',
#    'could be more concise',
#    '– while detail is important, some explanations could be slightly condensed for brevity without sacrificing clarity.',
#    'more visual/anecdotal elements',
#    '– though theoretical concepts are well']},
#  'final_response': "# **Understanding Seasons: Why the Earth Has Changing Weather Patterns**  \n\nSeasons are the result of **Earth’s axial tilt** and **its orbit around the Sun**. These factors determine how much sunlight different parts of the planet receive throughout the year, creating patterns of temperature and weather changes.  \n\n---\n\n## 🌍 **Why Do Seasons Occur?**  \n\n### **1. Earth’s Tilt and Orbit**  \nThe Earth is tilted at an **angle of 23.5 degrees** relative to its orbit around the Sun. This tilt remains **constant** (a concept called **axial stability**) as the Earth moves through space. Because of this inclination:  \n\n- Different regions receive **varying intensities of sunlight** at different times of the year.  \n- The **hemisphere tilted toward the Sun** experiences **summer**, while the opposite hemisphere—tilted away—has **winter**.  \n- When neither hemisphere is strongly tilted toward or away, milder conditions mark **spring** and **autumn**.  \n\n### **2. The Four Seasons and Their Causes**  \nThe Earth’s position in its orbit determines the four seasons:  \n\n#### ☀️ **Summer (June–August in the Northern Hemisphere, December–February in the Southern Hemisphere)**  \n- **Sunlight hits more directly**, leading to **warmer temperatures**.  \n- Regions experience **longer daylight hours**.  \n- Plants thrive, animals are most active, and humans often engage in outdoor activities.  \n\n#### ❄️ **Winter (December–February in the Northern Hemisphere, June–August in the Southern Hemisphere)**  \n- Sunlight strikes at a **less direct angle**, making temperatures **cooler**.  \n- **Shorter days** with longer nights.  \n- Many animals hibernate, and trees shed leaves in colder climates.  \n\n#### 🌸 **Spring (March–May in the Northern Hemisphere, September–November in the Southern Hemisphere)**  \n- Warmer temperatures return as sunlight intensity increases.  \n- New plant growth, blooming flowers, and awakening wildlife.  \n- Often seen as a time of **renewal and growth**.  \n\n#### 🍂 **Autumn (September–November in the Northern Hemisphere, March–May in the Southern Hemisphere)**  \n- Temperatures **gradually cool** as the Sun’s angle decreases.  \n- Leaves change colors and fall off trees (in many temperate regions).  \n- Animals prepare for winter by storing food or migrating.  \n\n---\n\n## 🌎 **Seasonal Differences Around the World**  \n\nSeasons vary depending on **latitude** and **proximity to large bodies of water**:  \n\n- **Equator (Tropics):** Experiences **minimal seasonal temperature changes**. Instead of four seasons, regions near the equator have **wet and dry seasons**.  \n- **Poles (Arctic & Antarctic):** Experience **extreme seasonal shifts**, with almost **continuous daylight in summer** and **24-hour darkness in winter**.  \n- **Coastal Areas vs. Inland Regions:** Large bodies of water moderate temperature changes, leading to **milder seasons** in coastal regions but **more extreme seasons** inland.  \n\n---\n\n## 🏞 **How Seasons Impact Life on Earth**  \n\nSeasons influence **ecosystems, agriculture, and human activities**:  \n\n- **Changing daylight and temperature** affect plant growth, animal migration, and weather patterns.  \n- **Agriculture depends on seasonal cycles**, with planting, growing, and harvesting timed according to the seasons.  \n- **Human cultures and festivals** are often tied to natural seasonal events (e.g., harvest festivals, winter holidays).  \n\n---\n\n## 🔬 **Additional Scientific Insights**  \n\n- **Seasonal Lag:** The Earth's surface retains heat, meaning the warmest and coldest periods typically **follow** the solstices by several weeks.  \n- **Equinox vs. Solstice:**  \n  - **Solstices (June 21 & December 21)**: When the Sun appears farthest north or south, marking the longest and shortest days.  \n  - **Equinoxes (March 21 & September 21)**: When day and night are nearly equal worldwide, marking transitions between summer/winter and spring/autumn.  \n\n--- ...

# %%
# initial_responses = result['initial_responses']
# final_response = result['final_response']

# print("\nInitial Responses:", initial_responses)
# print("final response:", final_response)
